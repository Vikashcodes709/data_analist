# %%
import panda as pd
df=pd.read-csv('orders.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import panda as pd
#       2 df=pd.read-csv('orders.csv')
#
# File ~\Desktop\skilllab_vikash\c2\8_sep_2026\panda.py:2
#       1 import panda as pd
# ----> 2 df=pd.read-csv('orders.csv')
#       3 df.info()
#       4 df.loc[15]
#
# AttributeError: module 'panda' has no attribute 'read' (consider renaming 'c:\Users\Vikash Singh\Desktop\skilllab_vikash\c2\8_sep_2026\panda.py' if it has the same name as a library you intended to import)
