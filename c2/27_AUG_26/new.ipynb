# %%
import pandas as pd 
s=pd.Series([10,20,30,40])
print (s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 s=pd.Series([10,20,30,40])
#       3 print (s)
#
# AttributeError: module 'pandas' has no attribute 'Series'

# %%
import pandas as pd

data = {
    'Name': ['Mahesh', 'Paani', 'Ramesh'],
    'Age': [25, 30, 35],
    'City': ['Mumbai', 'Banaras', 'Delhi'],
    'pincode': [221101, 221005, 221102],
    'Department': ['IT', 'CSE', 'Accounts'],
    'Skills': ['Python', 'Java', 'Data Analysis']
}

dept = pd.DataFrame(data)

dept
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 12
#       8     'Department': ['IT', 'CSE', 'Accounts'],
#       9     'Skills': ['Python', 'Java', 'Data Analysis']
#      10 }
#      11
# ---> 12 dept = pd.DataFrame(data)
#      13
#      14 dept
#      15
#
# AttributeError: module 'pandas' has no attribute 'DataFrame'

# %%
import pandas
